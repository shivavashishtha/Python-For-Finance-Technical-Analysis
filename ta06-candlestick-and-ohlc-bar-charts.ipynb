# %% [markdown]
# # Important Note!
# These notebooks are a part of the data resources I used in my training program, 'Python For Finance Nanodegree', wherein I train students in the fundamentals of using Python to analyze and understand financial data.
#
# Not to brag😅, but some of my students have in fact gone on to pursue highly rewarding careers in techno-finance after my program.
#
# Do feel free to hit me up for any doubts. Would love to help!
# <br><br>
# **Visit**: [Python For Finance Nanodegree](https://python.jobaaj.com/)<br>
# **Email**: contact@jobaaj.com<br>
# **Contact**: +91 73035 12500<br>

# %% [markdown]
# # Building Candlestick and OHLC Bar Charts Using Python

# %%
###### This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cufflinks as cf
from pandas_datareader import data

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning:
#
# The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.

# %% [markdown]
# ## Defining the Start and End Date

# %%
start="2005-01-01"
end="2022-01-01"

# %%
tickers=["TTM","TCS.NS","RELIANCE.NS","BHARTIARTL.NS"]

# %%
df=data.DataReader(name=tickers,data_source="yahoo",start=start,end=end)

# %%
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.Close.iplot()
# Out:
# <div>                            <div id="97a0b95c-5349-4341-8334-f2495d838f49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.swaplevel(axis=1).TTM
# Out:
# Attributes  Adj Close      Close       High        Low       Open     Volume
# Date
# 2005-01-03  10.217473  12.060000  12.250000  12.000000  12.220000   314900.0
# 2005-01-04   9.980251  11.780000  12.050000  11.760000  12.000000   273400.0
# 2005-01-05   9.607473  11.340000  11.580000  11.270000  11.580000   362600.0
# 2005-01-06   9.404142  11.100000  11.290000  11.040000  11.290000   243900.0
# 2005-01-07   9.573586  11.300000  11.330000  11.160000  11.250000    65300.0
# ...               ...        ...        ...        ...        ...        ...
# 2021-12-27  31.780001  31.780001  31.790001  31.160000  31.190001   678100.0
# 2021-12-28  31.719999  31.719999  32.080002  31.600000  32.080002  2110400.0
# 2021-12-29  31.549999  31.549999  31.660000  31.450001  31.600000   346900.0
# 2021-12-30  31.330000  31.330000  31.660000  31.309999  31.530001   481700.0
# 2021-12-31  32.090000  32.090000  32.369999  32.049999  32.180000   508400.0
#
# [4401 rows x 6 columns]

# %%
ttm=df.swaplevel(axis=1).TTM.copy()

# %%
ttm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4401 entries, 2005-01-03 to 2021-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  4280 non-null   float64
#  1   Close      4280 non-null   float64
#  2   High       4280 non-null   float64
#  3   Low        4280 non-null   float64
#  4   Open       4280 non-null   float64
#  5   Volume     4280 non-null   float64
# dtypes: float64(6)
# memory usage: 240.7 KB

# %%
ttm.iplot("candle")
# Out:
# <div>                            <div id="fa5a7dad-9384-431c-856c-178215d02984" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ttm.iplot("ohlc")
# Out:
# <div>                            <div id="fd8d8cff-2902-427e-9594-6decc0d31fdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ttm.loc["6-2006"].iplot("candle")
# Out:
# <div>                            <div id="8a26d4de-2ec0-47c9-b118-96f0ba5f6a51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ttm.loc["6-2006"].iplot("ohlc")
# Out:
# <div>                            <div id="226803ab-a873-47c7-a7a6-2cf465b6ba39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ![](https://a.c-dn.net/c/content/dam/publicsites/igcom/uk/images/ContentImage/BULLISH%20BEARISH%20CANDLESTICK-150620.jpg)
